# %%
from pathlib import Path
import SimpleITK as sitk

# %%
for cid in range(210):
    path=Path(f'/home/higuchi/Desktop/kits19/data/case_00{str(cid).zfill(3)}/segmentation.nii.gz')
    im=sitk.ReadImage(str(path))
    im=sitk.GetArrayFromImage(im)
    print(im.shape)
# Out:
# (512, 512, 611)
# (512, 512, 602)
# (512, 512, 261)
# (512, 512, 270)
# (512, 512, 64)
# (512, 512, 834)
# (512, 512, 157)
# (512, 512, 61)
# (512, 512, 227)
# (512, 512, 77)
# (512, 512, 50)
# (512, 512, 80)
# (512, 512, 89)
# (512, 512, 92)
# (512, 512, 439)
# (512, 512, 75)
# (512, 512, 178)
# (512, 512, 97)
# (512, 512, 121)
# (512, 512, 129)
# (512, 512, 96)
# (512, 512, 38)
# (512, 512, 541)
# (512, 512, 107)
# (512, 512, 85)
# (512, 512, 103)
# (512, 512, 302)
# (512, 512, 723)
# (512, 512, 98)
# (512, 512, 131)
# (512, 512, 38)
# (512, 512, 117)
# (512, 512, 189)
# (512, 512, 423)
# (512, 512, 110)
# (512, 512, 98)
# (512, 512, 163)
# (512, 512, 97)
# (512, 512, 32)
# (512, 512, 90)
# (512, 512, 207)
# (512, 512, 52)
# (512, 512, 301)
# (512, 512, 172)
# (512, 512, 101)
# (512, 512, 62)
# (512, 512, 159)
# (512, 512, 142)
# (512, 512, 85)
# (512, 512, 670)
# (512, 512, 96)
# (512, 512, 68)
# (512, 512, 673)
# (512, 512, 553)
# (512, 512, 104)
# (512, 512, 101)
# ...

# %%
    path=Path(f'/home/higuchi/Desktop/kits19/data/case_00185/segmentation.nii.gz')
    im=sitk.ReadImage(str(path))
    im=sitk.GetArrayFromImage(im)
    print(im.shape)
# Out:
# (512, 512, 235)
