# %%
import os
import glob

# %%
D_num=1
path=r"C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal"
glob.glob(os.path.join(path, f'case_00[0-1][0-7][0-9]/{D_num}/*.mha'))
# Out:
# ['C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000\\1\\image0.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000\\1\\image1.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000\\1\\image10.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000\\1\\image11.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000\\1\\image12.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000\\1\\image13.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000\\1\\image14.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000\\1\\image2.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000\\1\\image3.mha',
# ...

# %%
path_list=[]
for i in range(180):
    path_list+=glob.glob(os.path.join(path, f'case_00{str(i).zfill(3)}/{D_num}/*.mha'))
path_list
# Out:
# ['C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000/1\\image0.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000/1\\image1.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000/1\\image10.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000/1\\image11.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000/1\\image12.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000/1\\image13.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000/1\\image14.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000/1\\image2.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00000/1\\image3.mha',
# ...

# %%
a,b,c=[],[],[]

# %%
a.append(2)

# %%
c
# Out:
# []

# %%
[glob.glob(os.path.join(path, f'case_00{str(i).zfill(3)}/{D_num}/*.mha')) for i in range(180,210)]
# Out:
# [['C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image0.mha',
#   'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image1.mha',
#   'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image10.mha',
#   'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image11.mha',
#   'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image12.mha',
#   'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image13.mha',
#   'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image14.mha',
#   'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image15.mha',
#   'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image16.mha',
# ...

# %%
test_list=[]
for i in range(180,210):
    path_list+=glob.glob(os.path.join(path, f'case_00{str(i).zfill(3)}/{D_num}/*.mha'))
test_list
# Out:
# ['C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image0.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image1.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image10.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image11.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image12.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image13.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image14.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image15.mha',
#  'C:/Users/higuchi/Desktop/LAB/201906_/segmentation/data/image_sagittal\\case_00180/1\\image16.mha',
# ...
